# %%
import pandas as pd

# %%
ser = pd.Series(dtype = "float64")
print(ser)
# Out:
# Series([], dtype: float64)

# %%
import numpy as np

# simple array
data = np.array(['ab', 'ef', 'eg', 'kl', 'st'])

ser = pd.Series(data,index=[10, 11, 12, 13, 14])
print(ser)
# Out:
# 10    ab
# 11    ef
# 12    eg
# 13    kl
# 14    st
# dtype: object

# %%
list1 = ["hi","hello","how","are","you"]
ser = pd.Series(list1)
print(ser)
# Out:
# 0       hi
# 1    hello
# 2      how
# 3      are
# 4      you
# dtype: object

# %%
ser[2]
# Out:
# 'how'

# %%
dict1={'name':'Archana',
       'age':22,
       'place':'TVM'}
ser = pd.Series(dict1)
print(ser)
# Out:
# name     Archana
# age           22
# place        TVM
# dtype: object

# %%
ser['name']
# Out:
# 'Archana'

# %%
ser = pd.Series(15,index=[0,1,2,3,4,5])
print(ser)
# Out:
# 0    15
# 1    15
# 2    15
# 3    15
# 4    15
# 5    15
# dtype: int64

# %%
city1 = pd.Series([12,-6,8,-3])

# %%
city1
# Out:
# 0    12
# 1    -6
# 2     8
# 3    -3
# dtype: int64

# %%
city1.values
# Out:
# array([12, -6,  8, -3])

# %%
city1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
city2 = pd.Series([12,-6,8,-3], index=['day 1', 'day 2', 'day 3', 'day 4'])

# %%
city2
# Out:
# day 1    12
# day 2    -6
# day 3     8
# day 4    -3
# dtype: int64

# %%
city2['day 4']
# Out:
# -3

# %%
city2[['day 4','day 3']]
# Out:
# day 4   -3
# day 3    8
# dtype: int64

# %%
city2>0
# Out:
# day 1     True
# day 2    False
# day 3     True
# day 4    False
# dtype: bool

# %%
city2.min()
# Out:
# -6

# %%
city2.max()
# Out:
# 12

# %%
city2[city2>8]
# Out:
# day 1    12
# dtype: int64

# %%
city2[(city2>2)&(city2<9)]
# Out:
# day 3    8
# dtype: int64

# %%
city2+3
# Out:
# day 1    15
# day 2    -3
# day 3    11
# day 4     0
# dtype: int64

# %%
city2-3
# Out:
# day 1    9
# day 2   -9
# day 3    5
# day 4   -6
# dtype: int64

# %%
city2*3
# Out:
# day 1    36
# day 2   -18
# day 3    24
# day 4    -9
# dtype: int64

# %%
city2/4
# Out:
# day 1    3.00
# day 2   -1.50
# day 3    2.00
# day 4   -0.75
# dtype: float64

# %%
data = {'Kerala':28,'Andhra':25,'TN':31,'Karnataka':19,'Delhi':38}

# %%
data_ser = pd.Series(data)

# %%
data_ser
# Out:
# Kerala       28
# Andhra       25
# TN           31
# Karnataka    19
# Delhi        38
# dtype: int64

# %%
states = ['Andhra', 'Delhi', 'TN', 'MP', 'Kerala', 'Karnataka']
city3 = pd.Series(data_ser,index=states)
city3
# Out:
# Andhra       25.0
# Delhi        38.0
# TN           31.0
# MP            NaN
# Kerala       28.0
# Karnataka    19.0
# dtype: float64

# %%
city3.isna()
# Out:
# Andhra       False
# Delhi        False
# TN           False
# MP            True
# Kerala       False
# Karnataka    False
# dtype: bool

# %%
city3.notna()
# Out:
# Andhra        True
# Delhi         True
# TN            True
# MP           False
# Kerala        True
# Karnataka     True
# dtype: bool

# %%
city3.loc['Kerala']
# Out:
# 28.0

# %%
city3.iloc[4]
# Out:
# 28.0

# %%
city3.iloc[2:5]
# Out:
# TN        31.0
# MP         NaN
# Kerala    28.0
# dtype: float64

# %%
city3.tolist()
# Out:
# [25.0, 38.0, 31.0, nan, 28.0, 19.0]

# %%
city3.head(2)
# Out:
# Andhra    25.0
# Delhi     38.0
# dtype: float64

# %%
city3.tail(2)
# Out:
# Kerala       28.0
# Karnataka    19.0
# dtype: float64

# %%
### using data frame

# %%
data = {'Year':[2001,2002,2004,2005,2006],
        'States':['Kerala','TN','Andhra', 'Karnataka', 'Bihar'],
        'Pop':[300,250,280,400,360]}

# %%
pop_data = pd.DataFrame(data)
pop_data
# Out:
#    Year     States  Pop
# 0  2001     Kerala  300
# 1  2002         TN  250
# 2  2004     Andhra  280
# 3  2005  Karnataka  400
# 4  2006      Bihar  360

# %%
pop_data1 = pd.DataFrame(data,columns=['Year','States','Pop','Income'])

# %%
pop_data1
# Out:
#    Year     States  Pop Income
# 0  2001     Kerala  300    NaN
# 1  2002         TN  250    NaN
# 2  2004     Andhra  280    NaN
# 3  2005  Karnataka  400    NaN
# 4  2006      Bihar  360    NaN

# %%
pop_data1['States']
# Out:
# 0       Kerala
# 1           TN
# 2       Andhra
# 3    Karnataka
# 4        Bihar
# Name: States, dtype: object

# %%
pop_data1['Income'] =[20000,30000,25000,12000,15000]

# %%
pop_data1
# Out:
#    Year     States  Pop  Income
# 0  2001     Kerala  300   20000
# 1  2002         TN  250   30000
# 2  2004     Andhra  280   25000
# 3  2005  Karnataka  400   12000
# 4  2006      Bihar  360   15000

# %%
pop_data1['Debt'] = [320,450,200,150,140]
pop_data1
# Out:
#    Year     States  Pop  Income  Debt
# 0  2001     Kerala  300   20000   320
# 1  2002         TN  250   30000   450
# 2  2004     Andhra  280   25000   200
# 3  2005  Karnataka  400   12000   150
# 4  2006      Bihar  360   15000   140

# %%
pop_data1['savings'] = pop_data1['Income'] - pop_data1['Debt']

# %%
pop_data1
# Out:
#    Year     States  Pop  Income  Debt  savings
# 0  2001     Kerala  300   20000   320    19680
# 1  2002         TN  250   30000   450    29550
# 2  2004     Andhra  280   25000   200    24800
# 3  2005  Karnataka  400   12000   150    11850
# 4  2006      Bihar  360   15000   140    14860

# %%
pop_data1['expenditure'] = 600
pop_data1
# Out:
#    Year     States  Pop  Income  Debt  savings  expenditure
# 0  2001     Kerala  300   20000   320    19680          600
# 1  2002         TN  250   30000   450    29550          600
# 2  2004     Andhra  280   25000   200    24800          600
# 3  2005  Karnataka  400   12000   150    11850          600
# 4  2006      Bihar  360   15000   140    14860          600

# %%
del pop_data1['Pop']

# %%
pop_data1
# Out:
#    Year     States  Income  Debt  savings  expenditure
# 0  2001     Kerala   20000   320    19680          600
# 1  2002         TN   30000   450    29550          600
# 2  2004     Andhra   25000   200    24800          600
# 3  2005  Karnataka   12000   150    11850          600
# 4  2006      Bihar   15000   140    14860          600

# %%
pop_data1.drop(4)
# Out:
#    Year     States  Income  Debt  savings  expenditure
# 0  2001     Kerala   20000   320    19680          600
# 1  2002         TN   30000   450    29550          600
# 2  2004     Andhra   25000   200    24800          600
# 3  2005  Karnataka   12000   150    11850          600

# %%
pop_data1.drop('expenditure',axis=1)
# Out:
#    Year     States  Income  Debt  savings
# 0  2001     Kerala   20000   320    19680
# 1  2002         TN   30000   450    29550
# 2  2004     Andhra   25000   200    24800
# 3  2005  Karnataka   12000   150    11850
# 4  2006      Bihar   15000   140    14860

# %%
pop_data1.ndim
# Out:
# 2

# %%
pop_data1.size
# Out:
# 30

# %%
pop_data1
# Out:
#    Year     States  Income  Debt  savings  expenditure
# 0  2001     Kerala   20000   320    19680          600
# 1  2002         TN   30000   450    29550          600
# 2  2004     Andhra   25000   200    24800          600
# 3  2005  Karnataka   12000   150    11850          600
# 4  2006      Bihar   15000   140    14860          600

# %%
####  using data set

# %%
auto_data = pd.read_csv('/content/auto-mpg.csv')

# %%
auto_data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto_data.shape
# Out:
# (398, 9)

# %%
auto_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
auto_data.head(7)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500
# 6       1           chevrolet impala

# %%
auto_data.tail(2)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin     car name
# 396          82       1  ford ranger
# 397          82       1   chevy s-10

# %%
auto_data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
auto_data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
auto_data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
auto_data.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin  car name
# 0         False   False     False
# 1         False   False     False
# ...

# %%
auto_data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
auto_data.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
auto_data['cylinders'].nunique()
# Out:
# 5

# %%
auto_data['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
auto_data['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
auto_data['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
auto_data.groupby('origin')['mpg'].mean()
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %%
auto_data.groupby('cylinders')[['mpg','displacement']].mean()
# Out:
#                  mpg  displacement
# cylinders
# 3          20.550000     72.500000
# 4          29.286765    109.796569
# 5          27.366667    145.000000
# 6          19.985714    218.142857
# 8          14.963107    345.009709

# %%
auto_data.loc[:,['mpg','displacement']]
# Out:
#       mpg  displacement
# 0    18.0         307.0
# 1    15.0         350.0
# 2    18.0         318.0
# 3    16.0         304.0
# 4    17.0         302.0
# ..    ...           ...
# 393  27.0         140.0
# 394  44.0          97.0
# 395  32.0         135.0
# 396  28.0         120.0
# 397  31.0         119.0
#
# [398 rows x 2 columns]

# %%
auto_data.iloc[:,[0,2]].head()
# Out:
#     mpg  displacement
# 0  18.0         307.0
# 1  15.0         350.0
# 2  18.0         318.0
# 3  16.0         304.0
# 4  17.0         302.0

# %%
auto_data.iloc[100:110,[0,2]].head()
# Out:
#       mpg  displacement
# 100  18.0         250.0
# 101  23.0         198.0
# 102  26.0          97.0
# 103  11.0         400.0
# 104  12.0         400.0

# %%
auto_data.iloc[100:110,:4].head()
# Out:
#       mpg  cylinders  displacement horsepower
# 100  18.0          6         250.0         88
# 101  23.0          6         198.0         95
# 102  26.0          4          97.0         46
# 103  11.0          8         400.0        150
# 104  12.0          8         400.0        167
